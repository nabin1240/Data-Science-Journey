# %%
# १-डी एरे (1D Array)
a = np.array([1,2,3,4,5,])
print(a)
type(a)
# Out:
# [1 2 3 4 5]
# numpy.ndarray

# %%
#day 2
b = np.array([[1,2,3], [4,5,6]])
print(b)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
#day three 3 6 number items

arr = ([1,2,3,4,5,6])
print(arr)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
#yaslai 2 ota row ra column ma rakhne
kacho_list = ([1,2,3,4,5,6])
arr = np.array(kacho_list)
new_arr = arr.reshape(2,3)
print(new_arr)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
#data nikalne katne 
arr = np.array([10,20,30,40,50])
print(arr[1:4])
# Out:
# [20 30 40]

# %%
arr=[0]

# %%
#mathmatical operaiton
a = np.array([1,2,3])
b = np.array([10,10,20])
print(a+b)
# Out:
# [11 12 23]

# %%
print(a*b)
# Out:
# [10 20 60]

# %%
np.sum(a)
# Out:
# np.int64(6)

# %%
np.mean(a)
# Out:
# np.float64(2.0)

# %%
np.max(a)
# Out:
# np.int64(3)

# %%
np.max(b)
# Out:
# np.int64(10)

# %%
def greet():
    print("Hello Nabin")
greet()
# Out:
# Hello Nabi

# %%
def hello():
    print("I am learning python")
    
    
hello()
# Out:
# I am learning python

# %%
def student(name):
    print("Welcome",name)
student("Nabin")
student("Ram")
# Out:
# Welcome Nabin
# Welcome Ram

# %%
def add(a,b):
    print(a + b)
add(10,12)
# Out:
# 22

# %%
def name(nam):
    print("Welcome",nam)
name("Nabin")
name("Khanal")
# Out:
# Welcome Nabin
# Welcome Khanal

# %%
#Homework
def hello():
    print("I am learning python")
hello()
# Out:
# I am learning python

# %%
def student(name):
    print("Welcome:",name)
student("Nabin Khanal")
student("Krishna Khan")
# Out:
# Welcome: Nabin Khanal
# Welcome: Krishna Khan

# %%
def add (a,b):
    print(a + b)
add(5,89)
# Out:
# 94

# %%
def even_odd(num):
    if num % 2 == 0:
        print("Even")
    else:
        print("Odd")
even_odd(30)
# Out:
# Even

# %%
def number(num):
    if num % 2 == 0:
        print("Even")
    else:
        print("Odd")
number(80)
# Out:
# Even

# %%
def rk(k):
    if k % 2 == 0 :
        print("Even")
    else:
        print("Odd")
rk(50)     
rk(3)
# Out:
# Even
# Odd
