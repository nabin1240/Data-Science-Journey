# %%
# lesson 1 if  statement
age = 20
if age >= 18:
    print("Your are adult")
# Out:
# Your are adult

# %%
age = 18
if age >= 18:
    print("Adult")
else:
    print("Minor")
# Out:
# Adult

# %%
# marks result with pass / failll
marks = 45
if marks >= 30:
    print("Pass")
else:
    print("Faill")
# Out:
# Pass

# %%
age = int(input("Enter your age"))
if age >= 18:
    print("Adult")
else:
    print("Minor")
# Out:
# Enter your age 44
# Adult

# %%
#for Positive and Negative
num = int(input("Enter your numbe"))
if num >= 0 :
    print("Positive")
else:
    print("Negative")
# Out:
# Enter your numbe 0
# Positive

# %%
#Homework
age = int(input("Enter your age"))
if age >= 18:
    print("Your are adult")
else:
    print("Your are still Minor")
# Out:
# Enter your age 4
# Your are still Minor

# %%
#task 2 pass faill
marks = int(input("Enter your Marks"))
if marks >= 30 :
    print("Pass")
else:
    print("Faill")
# Out:
# Enter your Marks 3
# Faill

# %%
#Event & Odd
num = int(input("Enter number"))
if num % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Enter number 6
# Even

# %%
# bonus tips
for i in range(5):
    print("Nabin is Learning Python")
# Out:
# Nabin is Learning Python
# Nabin is Learning Python
# Nabin is Learning Python
# Nabin is Learning Python
# Nabin is Learning Python

# %%
income = 50000
if income >= 50000 :
    print("Your income is better than other")
else:
    print("You are so poor ")
# Out:
# Your income is better than other

# %%
income = int(input("Enter your income details"))
if income >= 500000:
    print("Too rich")
    
else:
    print("So poor")
# Out:
# Enter your income details 100000
# So poor

# %%
number = 0
if number >= 0:
    print("Positive")
else:
    print("Negative")
# Out:
# Positive

# %%
num = int(input("Enter number"))
if num % 2== 0 :
    print("Even")
else:
    print("Odd")
# Out:
# Enter number 0
# Even

# %%
for i in range (5):
    print("Nabin Khanal")
# Out:
# Nabin Khanal
# Nabin Khanal
# Nabin Khanal
# Nabin Khanal
# Nabin Khanal

# %%
rich = int(input("Enter Your Assets"))
if rich >= 50000:l
    pr
