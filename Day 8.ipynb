# %%
#Numpay
import numpy as np
numbers = np.array([10,20,30,40])
print(numbers)
# Out:
# [10 20 30 40]

# %%
#Math operaion
numbers = np.array([10,20,40])
print(numbers + 5)
# Out:
# [15 25 45]

# %%
numbers = np.array([20,34,35,64])
print(np.mean(numbers)) #Mean
# Out:
# 38.25

# %%
#max 
print(np.max(numbers))
# Out:
# 64

# %%
#min
print(np.min(numbers))
# Out:
# 20

# %%
data = np.array([5,10,15,20])
print(data)
print(np.mean(data))
# Out:
# [ 5 10 15 20]
# 12.5

# %%
#Homework
marks = np.array([50,60,70,80])
print(marks)
print(np.max(marks))
print(np.min(marks))
# Out:
# [50 60 70 80]
# 80
# 50

# %%
#Task 2 
num = np.array([20,30,50])
print(num + 10)

#task 3
marks = [60,70,90]
print(np.mean(marks))
# Out:
# [30 40 60]
# 73.33333333333333

# %%
#task 4
ages = np.array([20,21,22,])
print(np.mul(2(ages)))
# Out:
# <>:3: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
# <>:3: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
# C:\Users\knabi\AppData\Local\Temp\ipykernel_404\3164290208.py:3: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
#   print(np.mul(2(ages)))
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 3
#       1 #task 4
#       2 ages = np.array([20,21,22,])
# ----> 3 print(np.mul(2(ages)))
#
# File C:\python_codeit\venv\Lib\site-packages\numpy\__init__.py:805, in __getattr__(attr)
#     802     import numpy.char as char
#     803     return char.chararray
# --> 805 raise AttributeError(f"module {__name__!r} has no attribute {attr!r}")
#
# AttributeError: module 'numpy' has no attribute 'mul'
