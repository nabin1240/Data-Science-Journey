# %%
# Topic (isnull(), sum(), dropna(), fillina(), duplicate(), drop_duplicate() etc...
import pandas as pd
df = pd.read_excel("data.xlsx")
print(df.isnull())
print("ater cleaning:", df.dropna(axis=1 , how="all"))
duplicate_file = df.drop_duplicates()
print(duplicate_file)#Empty  column and row checking here
# Out:
#     Symbol    LTP  Point Change  % Change   Open   High    Low  Volume  \
# 0    False  False         False     False  False  False  False   False
# 1    False  False         False     False  False  False  False   False
# 2    False  False         False     False  False  False  False   False
# 3    False  False         False     False  False  False  False   False
# 4    False  False         False     False  False  False  False   False
# 5    False  False         False     False  False  False  False   False
# 6    False  False         False     False  False  False  False   False
# 7    False  False         False     False  False  False  False   False
# 8    False  False         False     False  False  False  False   False
# 9    False  False         False     False  False  False  False   False
# 10   False  False         False     False  False  False  False   False
# 11   False  False         False     False  False  False  False   False
# ...

# %%
#Lesson 1
print(df.isnull().sum()) # How many missing vale is including hare its finded
# Out:
# Symbol           0
# LTP              0
# Point Change     0
# % Change         0
# Open             0
#                 ..
# Column16371     19
# Column16372     19
# Column16373     19
# Column16374     19
# Column16375     19
# Length: 16384, dtype: int64

# %%
#Lesson 2 - Removing Missing Value
df = pd.read_excel("data.xlsx")
print(df.dropna())
# Out:
# Empty DataFrame
# ...

# %%
#Lesson 3 _ Full Missing Value
df = df.fillna(0)
print(df)
# Out:
# Empty DataFrame
# ...

# %%
#Lesson 4 - Check Duplicate Rows
print(df.duplicated())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# dtype: bool

# %%
# Better Version
print(df.duplicated().sum())
# Out:
# 0

# %%
#Lesson 5 - Remove Duplicates
df= df.drop_duplicates()
print(df)
# Out:
#       Symbol     LTP  Point Change  % Change    Open    High     Low   Volume  \
# 0     ACLBSL   960.0          11.0      1.16   977.4   977.4   954.0      740
# 1       ADBL   317.0           4.0      1.28   317.9   318.5   312.3    45333
# 2    ADBLD83  1051.9         -18.1     -1.69  1051.9  1051.9  1051.9       25
# 3        AHL   508.9          -6.1     -1.18   505.0   518.5   504.0    19181
# 4       AHPC   287.8           3.8      1.34   275.0   289.0   275.0   106730
# 5      AKJCL   418.0          16.0      3.98   402.0   420.0   402.0  1451995
# 6       AKPL   276.5           2.0      0.73   275.0   278.8   271.0   217426
# 7      ALBSL  1148.0          33.0      2.96  1086.0  1148.0  1086.0     9899
# 8      ALICL   455.2           2.9      0.64   459.9   459.9   452.0     8712
# 9       ANLB  6038.0         137.0      2.32  5901.0  6050.0  5733.0     1185
# 10       API   359.8           2.6      0.73   359.0   363.0   357.2   510631
# ...

# %%
import pandas as pd
df = pd. read_excel("data.xlsx")
print(df.isnull().sum())
df = df.dropna()
df = df.drop_duplicates()
print(df.head())
# Out:
# Symbol           0
# LTP              0
# Point Change     0
# % Change         0
# Open             0
#                 ..
# Column16371     19
# Column16372     19
# Column16373     19
# Column16374     19
# Column16375     19
# Length: 16384, dtype: int64
# Empty DataFrame
# ...

# %%
df = df.dropna(axis=1, how="all")
print(df.shape)
print(df.head())
# Out:
# (0, 0)
# Empty DataFrame
# Columns: []
# Index: []

# %%
print(df.isnull().sum())
# Out:
# Series([], dtype: float64)

# %%
df = df.dropna()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#Full Professional Cleaning Workflow
import pandas as pd
df = pd.read_excel("data.xlsx")
print("Before:", df.shape)
df = df.dropna(axis=1, how="all")
print("After removing empty coluns:", df.shape)
print(df.isnull().sum())
df = df. drop_duplicates()
print("Final shape:", df. shape)
print(df.head())
# Out:
# Before: (19, 16384)
# After removing empty coluns: (19, 9)
# Symbol          0
# LTP             0
# Point Change    0
# % Change        0
# Open            0
# High            0
# Low             0
# Volume          0
# Prev. Close     0
# dtype: int64
# Final shape: (19, 9)
#     Symbol     LTP  Point Change  % Change    Open    High     Low  Volume  \
# 0   ACLBSL   960.0          11.0      1.16   977.4   977.4   954.0     740
# 1     ADBL   317.0           4.0      1.28   317.9   318.5   312.3   45333
# 2  ADBLD83  1051.9         -18.1     -1.69  1051.9  1051.9  1051.9      25
# 3      AHL   508.9          -6.1     -1.18   505.0   518.5   504.0   19181
# 4     AHPC   287.8           3.8      1.34   275.0   289.0   275.0  106730
#
#    Prev. Close
# 0        949.0
# 1        313.0
# 2       1070.0
# 3        515.0
# 4        284.0

# %%
#homework
import pandas as pd
df = pd.read_excel("data.xlsx")
print("Befor Cleaning Data : ",df.shape)
df = df.dropna(axis=1, how="all")
print("After cleaning:", df.shape)
print(df.isnull().sum()) #missing value checking here
print(df.duplicated().sum())
df = df. drop_duplicates()
print("After removed duplicates value:", df.shape)
print(df)
# Out:
# Befor Cleaning Data :  (19, 16384)
# After cleaning: (19, 9)
# Symbol          0
# LTP             0
# Point Change    0
# % Change        0
# Open            0
# High            0
# Low             0
# Volume          0
# Prev. Close     0
# dtype: int64
# 0
# After removed duplicates value: (19, 9)
#       Symbol     LTP  Point Change  % Change    Open    High     Low   Volume  \
# 0     ACLBSL   960.0          11.0      1.16   977.4   977.4   954.0      740
# 1       ADBL   317.0           4.0      1.28   317.9   318.5   312.3    45333
# 2    ADBLD83  1051.9         -18.1     -1.69  1051.9  1051.9  1051.9       25
# 3        AHL   508.9          -6.1     -1.18   505.0   518.5   504.0    19181
# 4       AHPC   287.8           3.8      1.34   275.0   289.0   275.0   106730
# 5      AKJCL   418.0          16.0      3.98   402.0   420.0   402.0  1451995
# 6       AKPL   276.5           2.0      0.73   275.0   278.8   271.0   217426
# ...

# %%
#bonus task
import pandas as pd
df = pd.read_excel("data.xlsx")
print(df.shape)
df = df.dropna(axis=1, how="all")

#Highest LTP Stock
print("Lowest LTP value:",df.loc[df["LTP"].idxmin()])
print("HIghest LTP value:", df.loc[df["LTP"].idxmax()])
# Out:
# (19, 16384)
# Lowest LTP value: Symbol            AKPL
# LTP              276.5
# Point Change       2.0
# % Change          0.73
# Open             275.0
# High             278.8
# Low              271.0
# Volume          217426
# Prev. Close      274.5
# Name: 6, dtype: object
# HIghest LTP value: Symbol            ANLB
# LTP             6038.0
# Point Change     137.0
# % Change          2.32
# Open            5901.0
# High            6050.0
# Low             5733.0
# Volume            1185
# Prev. Close     5901.0
# Name: 9, dtype: object

# %%
# Clear version
import pandas as pd
df = pd.read_excel("data.xlsx")
print("Before Cleaning:", df. shape)
df = df.dropna(axis=1, how="all")
print("After Cleaning:", df.shape)
print(df.isnull().sum())
df = df.drop_du
print("After Removing Duplicates:", df.shape)
print("\nHighest LTP stock:")
print(df.loc[df["LTP"].idxmax()])
print("\nLowest LTP Stock:")
print(df.loc[df["LTP"].idxmin()])
# Out:
# Before Cleaning: (19, 16384)
# After Cleaning: (19, 9)
# Symbol          0
# LTP             0
# Point Change    0
# % Change        0
# Open            0
# High            0
# Low             0
# Volume          0
# Prev. Close     0
# dtype: int64
#       Symbol     LTP  Point Change  % Change    Open    High     Low   Volume  \
# 0     ACLBSL   960.0          11.0      1.16   977.4   977.4   954.0      740
# 1       ADBL   317.0           4.0      1.28   317.9   318.5   312.3    45333
# 2    ADBLD83  1051.9         -18.1     -1.69  1051.9  1051.9  1051.9       25
# 3        AHL   508.9          -6.1     -1.18   505.0   518.5   504.0    19181
# 4       AHPC   287.8           3.8      1.34   275.0   289.0   275.0   106730
# 5      AKJCL   418.0          16.0      3.98   402.0   420.0   402.0  1451995
# 6       AKPL   276.5           2.0      0.73   275.0   278.8   271.0   217426
# 7      ALBSL  1148.0          33.0      2.96  1086.0  1148.0  1086.0     9899
# ...
