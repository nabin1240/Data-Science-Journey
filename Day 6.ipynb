# %%
#pindas installation

import pandas as pd

# %%
#list bat series banaune
data = [10, 20, 30, 40]
s = pd.Series(data)
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
#Dictionary bata  DataFrame banaune
student_data = { 
    'Name' : ['Ram', 'Sita' , 'Hari'],
    'Age' : [20, 21, 19],
    'City' : ['Kathamandu', 'Pokhara', 'Butwal']
}
df = pd.DataFrame(student_data)
print(df)
# Out:
#    Name  Age        City
# 0   Ram   20  Kathamandu
# 1  Sita   21     Pokhara
# 2  Hari   19      Butwal

# %%
#Day 6  list function Lesson 1
fruits = ["Apple", "Banana", "Mango"]
print(fruits)
# Out:
# ['Apple', 'Banana', 'Mango']

# %%
#lesson 2
student = ["Nabin", "Nikhil", "Sanjay","Sagar"]
print(student[0])
print(student[1])
print(student[2])
print(student[3])
# Out:
# Nabin
# Nikhil
# Sanjay
# Sagar

# %%
#Lesson 3
fruits = ["apple","banana","mango"]
fruits[1] = "orange"
print(fruits)
# Out:
# ['apple', 'orange', 'mango']

# %%
#Lesson add item
fruits = ["apple","banana","orange"]
fruits.append("mango") # added mango using append()
print(fruits)
# Out:
# ['apple', 'banana', 'orange', 'mango']

# %%
#Lesson 5 Remove Item
fruits = ["orange","banana","Apple"]
fruits.remove("banana")
print(fruits)
# Out:
# ['orange', 'Apple']

# %%
#lesson 6 : Loop with List
fruits = ["Apple","Banana","Mango"]
for fruit in fruits:
    print(fruit)
# Out:
# Apple
# Banana
# Mango

# %%
#practic Task
numbers = [10,20,30,40]
print(numbers[0])
print(numbers[3])
print(numbers[2])
# Out:
# 10
# 40
# 30

# %%
#Homework
movies = ["Movie1","Movie2","Movie3"]
print(movies)
# Out:
# ['Movie1', 'Movie2', 'Movie3']

# %%
#create List
colors = ["Red","Blue"]
colors.append("Green")
print(colors)
# Out:
# ['Red', 'Blue', 'Green']

# %%
#remove items
colors = ["Red","Green","Blue"]
colors.remove("Red")
print(colors)
# Out:
# ['Green', 'Blue']

# %%
worker = ["A","B","C","D"]
for work in worker:
    print(work)
# Out:
# A
# B
# C
# D

# %%
wland = ["icland","irco"]
wland.app("h")
print(wland)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 2
#       1 wland = ["icland","irco"]
# ----> 2 wland.add("h")
#       3 print(wland)
#
# AttributeError: 'list' object has no attribute 'add'
