# %%
import numpy as np   # 
number = np.array([20,40,39,30])
print(number[0])
print(number[2])
# Out:
# 20
# 39

# %%
print(number[-1]) # last array data given us
# Out:
# 30

# %%
#1 : 4 (Start 1 to befor 4 data output
print(number[1:4])
# Out:
# [40 39 30]

# %%
print(number[3])
# Out:
# 30

# %%
# From index 2 to End
print(number[3])
# Out:
# 30

# %%
#Practic Task
data = np.array([5,10,15,20])
print(data[1])
print(data[-1])
print(data[1:4])
# Out:
# 10
# 20
# [10 15 20]

# %%
#homework Task 1
marks = np.array([50,60,70,80,90,100])
print(marks[0])
print(marks[-1])
# Out:
# 50
# 100

# %%
# Task 2 Print value from index 1 to 4
nps = np.array([20,30,40,50,60])
print(nps[1:4])
# Out:
# [30 40 50]

# %%
# task 3 print first 4 value
workday = np.array([40,50,60,70,90,40])
print(workday[0:4])
# Out:
# [40 50 60 70]

# %%
# task 4 print value index 2 to end
players = np.array([30,40,49,50,60])
print(players[2:])
# Out:
# [49 50 60]

# %%
pr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(players.mean())
#
# NameError: name 'players' is not defined
