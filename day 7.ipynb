# %%
#touple

# %%
fruits = ("Apple","Banana","Mango")
print(fruits)
print(fruits[0])
# Out:
# ('Apple', 'Banana', 'Mango')
# Apple

# %%
#Student Details 
student = {
    "name" : "Nabin",
    "age" : 22,
    "country" : "Nepal"}
print(student)
student["collage"] = "NSU" # add new data
print(student)
# Out:
# {'name': 'Nabin', 'age': 22, 'country': 'Nepal'}
# {'name': 'Nabin', 'age': 22, 'country': 'Nepal', 'collage': 'NSU'}

# %%
student = { 
    "name" : "Nabin",
    "age" :  22,
    "country" : "Nepal"
}
print(student["age"])
print(student["country"])
# Out:
# 22
# Nepal

# %%
#Lessonn 5 Loop Dictionary
for key, value in student.items():
    print(key,value)
# Out:
# name Nabin
# age 22
# country Nepal

# %%
#Practice Task dictionary model
car = {
    "brand" : "Toyota",
    "color" : "Black",
    "model" : 222
}
print(car["brand"])
print(car["model"])
# Out:
# Toyota
# 222

# %%
#homework
number = (20,30,40)
print(number)
print(number[0])
# Out:
# (20, 30, 40)
# 20

# %%
#dictionary task 2
person = {
    "name": "Nabin Khanal",
    "age" : 22,
}
print(person["name"])
print(person["age"])
# Out:
# Nabin Khanal
# 22
# {'name': 'Nabin Khanal', 'age': 22, 'country': 'Nepal'}

# %%
# task 4 
for key, value in person.items():
    print(key,value)
# Out:
# name Nabin Khanal
# age 22
# slice('country', None, None) Nepal
# country Nepal
# country : Nepal
