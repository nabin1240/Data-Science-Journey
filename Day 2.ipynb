# %%
#Development :-
x = 10
y = 20
x < y 
     # x less than y given this data
# Out:
# True

# %%
x<=y
# Out:
# True

# %%
z = 20
x<= y
# Out:
# True

# %%
#greater than (>)
x > y # returns false because value is in x is not greater y
y >z
# Out:
# False

# %%
x == y # returns false because value in 'x' in not equal to y
# Out:
# False

# %%
y == z # returns true because it is equal value z
# Out:
# True

# %%
#not equal to (!=)
x != y # returns true because value in x is not equal to value in y
# Out:
# True

# %%
y != z # returns false because value in y is equal to value in z
# Out:
# False

# %%
#they are used to update the value in a variable
#additional assignement  (+=)
v= 10 
#add value 7 in vareable 'v'
v += 10
print("new values of V:",v)
# Out:
# new values of V: 20

# %%
#subtraction assignment (-=)
#subtract 9 from the value 'v'
v-= 9
print("New Value", v)
# Out:
# New Value 11

# %%
#multiplication Assignment (*=)
#multiply the value in 'v' with 2 
v *= 2
print ("new value:" , v)
# Out:
# new value: 22

# %%
#Divsion Assignment (/=)
#divide value in v by 3
v /= 3
print("new value:",v)
# Out:
# new value: 7.333333333333333

# %%
#int div assignment (//=)
a = 13
#int divide a by 5
a //=5
print("New Value:", a)
# Out:
# New Value: 2

# %%
#membership operators
#in m returns 'true if the given value is 'in' the variable
lst = [10,12,15,16]
20 in lst # false because 20 not in lst
# Out:
# False

# %%
12 in lst # true because 12 in lst
# Out:
# True

# %% [markdown]
# #conditional operator

# %%
# single conditon(if)
x= 10
#print 'true' if value in x is greater than 5
syntax : 
if condition :
    code if true
# Out:
#   Cell In[44], line 4
#     syntax :
#              ^
# SyntaxError: invalid syntax

# %%
x = 10
if x >= 5 :
    print ("the condition is true")
# Out:
# the condition is true

# %%
#Tow Condition ( if else)
syntax 
if conditon :
    code if true
else:
    code if false

# %%
#print true is x > = 5 else print false
x=3
if x>= 5:
    print ("true")
else:
    print("false")
# Out:
# false

# %%
#multiple conditon (if elif elif ...else)
syntax :
if con1 :
    code if true
elif con2 :
    code if con2 is true
..
..
..
..
..
else:
    default conditon
# Out:
#   Cell In[58], line 4
#     code if true
#     ^
# SyntaxError: expected 'else' after 'if' expression

# %%
#print either a number is +ve, -ve or zero  
x =0
if x> 0:
    print("Positive")
elif x<0:
    print("Negative")
else:
    print("Zero")
# Out:
# Zero

# %%
#Ask number 1 to 3 from user 
#for 1 offer different type of tea 
#for 2 offer different type of koffee
# for 3 offer differ type of cold-drink
# for else exit the program

# %%
ch = input("enter ur choice 1 for tea, 2 for koffe , 3 for drink")
# Out:
# enter ur choice 1 for tea, 2 for koffe , 3 for drink 2

# %%
name = input("Enter Your Name")
print("Hello",name)
# Out:
# Enter Your Name Nabin
# Hello Nabin

# %%
name = "Nabin"  #String
age = 22 # integer
height = 5.4 # Float
is_student = True # boolean
print(type(name))
print(type(age))
print(type(height))
print(type(is_student))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
name = input("Enter Your Name")
print("Hello",name)
# Out:
# Enter Your Name nabin
# Hello nabin

# %%
# operation 
x =10 
y = 5
a = x>y  # Grater than >
print(a)
a = x < y #Less Than <
print(a)

a = x == y  # Equal ==
print(a)
a = x !=y   # Not Equal !
print(a)
a = x = y   # substrack gare paxi aaunxa
print(a)
# Out:
# True
# False
# False
# True
# 5

# %%
# Practic Task
age = int(input("Enter Your Age"))
print(age)
print(age > 18)
# Out:
# Enter Your Age 11
# 11
# False

# %%
#Homework 

#Create 4 veriable
name = "Nabin"
age = 22
height = 5.4
student = True
print(type(name))
print(type(age))
print(type(height))
print(type(student))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
# Task 2 
city = input("Enter Your City")
print("I Live In",city)
# Out:
# Enter Your City Nepal
# I Live In Nepal

# %%
# Task 3
a = 15
b = 20
c = a > b # false
print(c)
c = a < b 
print(c)  # true
c = a == b
print(c) #  Equal false
c = a != b 
print(c) # Not equal check
# Out:
# False
# True
# False
# True

# %%
a = 40
b = 30
print(a > b)
print( a < b)
print(a == b)
print( a !==b)
print( a
# Out:
# False
# True
# False
# True

# %%
name = "Nabin" #string
age =  22 #integer
height = 4.5 # float
student = True # boll
print(type(age),(type(name),(type(height),(type(student)))))
# Out:
# <class 'int'> (<class 'str'>, (<class 'float'>, <class 'bool'>))

# %%
age = int(input("enter Your age"))
print("My age:",age)
# Out:
# enter Your age 33
# My age: 33

# %%
a = 2
b = 4
print(a > b),(a < b),(a == b), (a != b)
# Out:
# False
# (None, True, False, True)

# %%
input_Your_City = str(input("Enter your CITY"))
print(input_Your_City
# Out:
# Enter your CITY nepal

# %%
name = " nabin"
age = 33
height = 4.3
worker = False
print(type(name),(type(age),(type(height),(type(worker)))))
# Out:
# <class 'str'> (<class 'int'>, (<class 'float'>, <class 'bool'>))

# %%
worker_name = str(input("Enter your name"))
print("Your Name:", worker_name)
# Out:
# Enter your name nabin
# Your Name: nabin

# %%
a = 30
b = 4
print(a > b, a < b, a == b, a != b)
# Out:
# True False False True
