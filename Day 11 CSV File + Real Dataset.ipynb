# %%
import pandas as pd

df = pd.read_excel("data.xlsx")

print(df)
# Out:
#       Symbol     LTP  Point Change  % Change    Open    High     Low   Volume  \
# 0     ACLBSL   960.0          11.0      1.16   977.4   977.4   954.0      740
# 1       ADBL   317.0           4.0      1.28   317.9   318.5   312.3    45333
# 2    ADBLD83  1051.9         -18.1     -1.69  1051.9  1051.9  1051.9       25
# 3        AHL   508.9          -6.1     -1.18   505.0   518.5   504.0    19181
# 4       AHPC   287.8           3.8      1.34   275.0   289.0   275.0   106730
# 5      AKJCL   418.0          16.0      3.98   402.0   420.0   402.0  1451995
# 6       AKPL   276.5           2.0      0.73   275.0   278.8   271.0   217426
# 7      ALBSL  1148.0          33.0      2.96  1086.0  1148.0  1086.0     9899
# 8      ALICL   455.2           2.9      0.64   459.9   459.9   452.0     8712
# 9       ANLB  6038.0         137.0      2.32  5901.0  6050.0  5733.0     1185
# 10       API   359.8           2.6      0.73   359.0   363.0   357.2   510631
# ...

# %%
print(df[["Symbol","LTP","% Change","Volume"]].head())
# Out:
#     Symbol     LTP  % Change  Volume
# 0   ACLBSL   960.0      1.16     740
# 1     ADBL   317.0      1.28   45333
# 2  ADBLD83  1051.9     -1.69      25
# 3      AHL   508.9     -1.18   19181
# 4     AHPC   287.8      1.34  106730

# %%
print(df["LTP"].min())
# Out:
# 276.5

# %%
print(df["LTP"].max())
# Out:
# 6038.0

# %%
print(df["Volume"].max())
# Out:
# 1451995

# %%
import matplotlib.pyplot as plt
top5 = df.head()
plt.bar(top5["Symbol"], top5["LTP"])
plt.title("Top 5 Stock Prices")
plt.xlabel("Symbol")
plt.ylabel("LTP")
plt.show()

# %%
print(df[["Symbol", "LTP"]])
# Out:
#       Symbol     LTP
# 0     ACLBSL   960.0
# 1       ADBL   317.0
# 2    ADBLD83  1051.9
# 3        AHL   508.9
# 4       AHPC   287.8
# 5      AKJCL   418.0
# 6       AKPL   276.5
# 7      ALBSL  1148.0
# 8      ALICL   455.2
# 9       ANLB  6038.0
# 10       API   359.8
# 11     AVYAN  1148.0
# 12  BANDIPUR   866.5
# 13     BARUN   357.5
# 14       BBC  4815.0
# 15      BEDC   381.1
# 16       BFC   460.0
# 17      BGWT   671.8
# 18      BHCL   593.0

# %%
print(df.shape) # items of data
# Out:
# (19, 16384)

# %%
print(df.columns)
# Out:
# Index(['Symbol', 'LTP', 'Point Change', '% Change', 'Open', 'High', 'Low',
#        'Volume', 'Prev. Close', 'Column1',
#        ...
#        'Column16366', 'Column16367', 'Column16368', 'Column16369',
#        'Column16370', 'Column16371', 'Column16372', 'Column16373',
#        'Column16374', 'Column16375'],
#       dtype='str', length=16384)

# %%
#Homework
print(df[["Symbol", "LTP", "Volume"]].head())
# Out:
#     Symbol     LTP  Volume
# 0   ACLBSL   960.0     740
# 1     ADBL   317.0   45333
# 2  ADBLD83  1051.9      25
# 3      AHL   508.9   19181
# 4     AHPC   287.8  106730

# %%
print(df["LTP"].mean())  #Task 2
# Out:
# 1111.2631578947367

# %%
print(df["LTP"].max()) #max value of Ltp task 3
# Out:
# 6038.0

# %%
print(df["LTP"].min()) #Lowest value of LTP task 4
# Out:
# 276.5

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_excel("data.xlsx")
print(df[["Symbol", "LTP", "Volume"]].head(10))
plt.figure(figsize=(20,8))
pplt.title("All Stock Data")
plt.xlabel("Symbol")
plt.ylabel("LTP")
plt.xticks(rotation=90)
plt.show()
# Out:
#     Symbol     LTP   Volume
# 0   ACLBSL   960.0      740
# 1     ADBL   317.0    45333
# 2  ADBLD83  1051.9       25
# 3      AHL   508.9    19181
# 4     AHPC   287.8   106730
# 5    AKJCL   418.0  1451995
# 6     AKPL   276.5   217426
# 7    ALBSL  1148.0     9899
# 8    ALICL   455.2     8712
# 9     ANLB  6038.0     1185
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 6
#       2 import matplotlib.pyplot as plt
#       3 df = pd.read_excel("data.xlsx")
#       4 print(df[["Symbol", "LTP", "Volume"]].head(10))
#       5 plt.figure(figsize=(20,8))
# ----> 6 plt.bar(df["Symbol"],df(["LTP"]))
#       7 plt.title("All Stock Data")
#       8 plt.xlabel("Symbol")
#       9 plt.ylabel("LTP")
#
# TypeError: 'DataFrame' object is not callable
