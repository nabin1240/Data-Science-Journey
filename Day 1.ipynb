# %%
#first program in python
print("hello world")
w = 10
print(10)
# Out:
# hello world
# 10

# %%
#python 
x= 10
y= 10
z= x+y
print("the sum is",z)


h = 20
y = 30
u = h / y
print("yo multiply" , u)
# Out:
# the sum is 20
# yo multiply 0.6666666666666666

# %%
x = 10
y = 1
a = x*y
print("this", a)
# Out:
# this 10

# %%
#variables names varaib always starts with a letter 
name of variable name cannot have spaces

# %%
a = 10
print(a)
# Out:
# 10

# %%
a1 = "nabin"
print(a1)
# Out:
# nabin

# %%
my_name = "nabin Khanal"
print(my_name)
# Out:
# nabin Khanal

# %%
#Data : any values given by the user in to the computer (program)
# in python broadly we have two different type of data type
most basic type of data, they cannot be futter simplified int, float, string
int :- values with out decimals (10, -6, 16)
float : - values with decimals (10.5, -6.36, 18.62)
string: - values enclosed with '', ('a', '10.6', '-16.32', '@gmail.com')
b) Derived Data Type
data type made by combining one or more fundamental data types
list, tup

# %%
#extend (), this method is used to add two or more items in a existnng list the new items can be either list,tuple,

# %%
int
y= -16.5 
type(y)
# Out:
# float

# %%
z= 10
type(z)
# Out:
# int

# %%
x=10
type(x)
# Out:
# int

# %%
float(x)
# Out:
# 10.0

# %%
int(x)
# Out:
# 10

# %%
str(x)
# Out:
# '10'

# %%
#write a program to store 10 and 11 in two dif var and print sum
x= 10
y= 11
z= x+y
print("the sume is", z)
# Out:
# the sume is 21

# %%
x = 100
y=1
z=x*y
print("sum",z)
# Out:
# sum 100

# %%
#user input alllows user to enter his/her values in to the program
a = input ("enter first number")

b = input ("enter second number")
s = a*b
print("product", s)

# %%
 #now changing the values 
a = input("enter first number")
a = float(a)
b = input("enter second number")
b = float(b)
s = a*b
# Out:
# enter first number 25
# enter second number 36

# %%
#Ask ur name and ur father's name and print
un = input("enter ur name")
ufn = input("enter ur father's name")
print("Your name:",un)
print("Your father's Name:",ufn)
# Out:
# enter ur name nabin
# enter ur father's name jalandhar
# Your name: nabin
# Your father's Name: jalandhar

# %%
#practice ask lenght, breadth,height with user and print the volum
l = input("enter length")
l= float(l)
b = input("enter bredth")
b = float(b)
h = input("enter height")
h = float(h)
v = l*b*h
print("Volum:",v)
# Out:
# enter length 12
# enter bredth 25

# %%
#practice ask lenght, breadth,height with user and print the volum
ll = input("enter length")
ll= float(ll)
bb = input("enter bredth")
bb = float(bb)
hh = input("enter height")
hh = float(hh)
v = ll*bb*hh
print("Volum:",v)
# Out:
# enter length 19
# enter bredth 20
# enter height 11
# Volum: 4180.0

# %%
operators and operations
#sing and symbolls that tell what operations is to be performed
#operation : action take over the data

# %%
#Arithmetic operator ( group of symbols ( + , - , * , //, %, **)

#logical operator ( and  , or , not)
#compariosion operator(Relation 0) ( <, <= , >, >=, !=)

# Assignment Operrator (=, +=, -=, /=, //=, %=, **)

#Membership operatior (in, not, in )

# %%
# (/) (ineger divison)
x = 13
y = 3
x / y
# Out:
# 4.333333333333333

# %%
#floor divison(//) (returns the quotient part)
x // y
# Out:
# 4

# %%
# Moduar Divison (%) (return the remainder)
x % y
# Out:
# 1

# %%
#Exponentail 2 the power 8
2**8
# Out:
# 256

# %%
#Logical operators (and , or , not)
class (run) (pale)
1 boy and 1 girls
2 boys (false)
2 girls(false)
and : final oputput is true, if all the condition are true
1 boys or 1 girls
1 boys ok
1 girl ok
or: final output  is true, if anyone of the given conditon is true
not : final output is false if the outcome is true and vice versa

# %%
x= 10
y= 20
x>30 and y>5
# Out:
# False

# %%
#or
x = 10
y = 20
x <5 or y>10
# Out:
# True

# %%
#not
not(x <5 or y > 10)
# Out:
# False

# %%
not(x >30 and y >5)
# Out:
# True

# %%
n = 100
nk = 200
n > 5 or y >10
# Out:
# True

# %%
name = (["nabin", "khanal","jhapa"])
print(name)
# Out:
# ['nabin', 'khanal', 'jhapa']

# %%
type(name)
# Out:
# list

# %%
str(name)
# Out:
# "['nabin', 'khanal', 'jhapa']"

# %%
tarkari = ["alu", "pyaj", "golbheda"] #change the list 
tarkari[0] = "kauli"
print(tarkari)
# Out:
# ['kauli', 'pyaj', 'golbheda']

# %%
#tuple
location = (27.7, 85.3)
print(location)
# Out:
# (27.7, 85.3)

# %%
type(location)
# Out:
# tuple

# %%
print("Hello Nabin") #print 
print("I am Learning Data Science")
# Out:
# Hello Nabin
# I am Learning Data Science

# %%
name = "Nabin"   #variable
age = 22
country = "Nepal"
print(name)
print(age)
print(country)
# Out:
# Nabin
# 22
# Nepal

# %%
a = 10 #Math with python
b = 20
print(a + b)
print(a - b)
print(a * b)
print(a / b)
# Out:
# 30
# -10
# 200
# 0.5

# %%
name = "Nabin"
age = 22
country = "Nepal"
print(name)
print(age)
print(country)
# Out:
# Nabin
# 22
# Nepal

# %%
# 3 variable using python
name = "Nabin"
age = 22
favorite_food = "Apple"
print(name,age,favorite_food)
# Out:
# Nabin 22 Apple

# %%
x = 20
y = 4
print(x + y) #add
print(x - y) # subtract
print(x * y) #multiply
print(x / y) # divide
# Out:
# 24
# 16
# 80
# 5.0

# %%
#Why I Want To Learn Data Science
print("For a Passive Job")
print("For Company Data Analysis")
print("For Export In The World ")
# Out:
# For a Passive Job
# For Company Data Analysis
# For Export In The World

# %%
print("Nabin")
# Out:
# Nabin

# %%
name = "Nabin"
age = 22
student = "BA in economices"
print(name,age,student)
# Out:
# Nabin 22 BA in economices

# %%
a = 20
b = 30
print("Add:",a +b,"Subtract:", a -

# %%
name_k = "Nabin"
age_k = 34
student_k = "Bachelor"
print("All student details:",name_k,age_)
# Out:
#   Cell In[2], line 3
#     student_k =
#                 ^
# SyntaxError: invalid syntax
